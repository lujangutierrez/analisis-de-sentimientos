# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#df_deaths = pd.read_csv('cause_of_deaths.csv')

# %%
df_deaths = pd.read_csv('cause_of_deaths.csv')

# %%
pais = 'Country/Territory'
anio = 'Year' 
data = pd.concat([df_deaths['Year'],df_deaths[pais]], axis=1) #me lo va a traer a en el eje 1
print(data.head(20)) #de la variable data me trae las primeras 20
#plt.show()
# Out:
#     Year Country/Territory
# 0   1990       Afghanistan
# 1   1991       Afghanistan
# 2   1992       Afghanistan
# 3   1993       Afghanistan
# 4   1994       Afghanistan
# 5   1995       Afghanistan
# 6   1996       Afghanistan
# 7   1997       Afghanistan
# 8   1998       Afghanistan
# 9   1999       Afghanistan
# 10  2000       Afghanistan
# 11  2001       Afghanistan
# 12  2002       Afghanistan
# 13  2003       Afghanistan
# 14  2004       Afghanistan
# 15  2005       Afghanistan
# 16  2006       Afghanistan
# 17  2007       Afghanistan
# 18  2008       Afghanistan
# 19  2009       Afghanistan

# %%
verAnios = sns.displot(df_deaths['Year'])
plt.show()

# %%
df_deaths.plot(kind='scatter', x='Year', y='Meningitis')
plt.show()

# %%
plt.bar(df_deaths['Year'], df_deaths['Meningitis'])
plt.show()

# %%
colores = ['85C7DE', 'C6DBF0', '8FCB9B', 'F0CF65', 'D7816A', 'E5989B', 'FFCDB2', 'C1839F']

# %%
haiti = df_deaths[df_deaths["Country/Territory"]=="Haiti"]
nepal = df_deaths[df_deaths["Country/Territory"]=="Nepal"]
moldavia = df_deaths[df_deaths["Country/Territory"]=="Moldova"]
colores = ['85C7DE', 'C6DBF0', '8FCB9B', 'F0CF65', 'D7816A', 'E5989B', 'FFCDB2', 'C1839F'] 
paisesPobres = [haiti, nepal, moldavia]
anio2015 = df_deaths[df_deaths["Year"]=="2015"]

plt.pie(2015,
    labels = paisesPobres,
    colors=colores)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4780\1727216639.py in <module>
#       6 anio2015 = df_deaths[df_deaths["Year"]=="2015"]
#       7
# ----> 8 plt.pie(2015,
#       9     labels = paisesPobres,
#      10     colors=colores)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2754         textprops=None, center=(0, 0), frame=False,
#    2755         rotatelabels=False, *, normalize=True, data=None):
# -> 2756     return gca().pie(
#    2757         x, explode=explode, labels=labels, colors=colors,
#    2758         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ...

# %%
Argentina = df_deaths[df_deaths["Country/Territory"]=="Argentina"]
Uganda = df_deaths[df_deaths["Country/Territory"]=="Uganda"]
Argentina.head()
# Out:
#     Country/Territory Code  Year  Meningitis  \
# 210         Argentina  ARG  1990         772
# 211         Argentina  ARG  1991         757
# 212         Argentina  ARG  1992         732
# 213         Argentina  ARG  1993         731
# 214         Argentina  ARG  1994         698
#
#      Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 210                                     4983                 1494
# 211                                     5161                 1526
# 212                                     5383                 1594
# 213                                     5609                 1644
# 214                                     5843                 1670
#
#      Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 210                      1323        9      1128                    2024  ...
# 211                      1323        9      1120                    2007  ...
# ...
